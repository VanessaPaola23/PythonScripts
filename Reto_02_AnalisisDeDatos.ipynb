# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaPaola23/PythonScripts/blob/main/Reto_02_AnalisisDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/DatasetsBEDU/near_earth_objects-jan_feb_1995-clean.csv',index_col=0)
df.head()
# Out:
#         id                name  is_potentially_hazardous_asteroid  \
# 0  2154652  154652 (2004 EP20)                              False
# 1  3153509           (2003 HM)                               True
# 2  3516633           (2010 HA)                              False
# 3  3837644          (2019 AY3)                              False
# 4  3843493           (2019 PY)                              False
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         44.111820
# 3                                         46.190746
# 4                                         22.108281
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          1995-01-07
# 1                                        215.794305          1995-01-07
# ...

# %%
diameter = df['estimated_diameter.meters.estimated_diameter_max']
rango_diameter=diameter.max() - diameter.min()
print(f'Rango: de diametros: {rango_diameter:,.2f}')
# Out:
# Rango: de diametros: 6,513.91

# %%
segmentos = pd.cut(diameter, 20)
df['estimated_diameter.meters.estimated_diameter_max'].groupby(segmentos).count()
# Out:
# estimated_diameter.meters.estimated_diameter_max
# (-3.535, 328.674]       207
# (328.674, 654.369]       67
# (654.369, 980.065]       24
# (980.065, 1305.76]       18
# (1305.76, 1631.455]       4
# (1631.455, 1957.15]       6
# (1957.15, 2282.846]       1
# (2282.846, 2608.541]      1
# (2608.541, 2934.236]      1
# (2934.236, 3259.931]      1
# (3259.931, 3585.627]      1
# (3585.627, 3911.322]      1
# (3911.322, 4237.017]      0
# (4237.017, 4562.712]      0
# (4562.712, 4888.408]      0
# (4888.408, 5214.103]      0
# (5214.103, 5539.798]      0
# (5539.798, 5865.493]      0
# (5865.493, 6191.189]      0
# (6191.189, 6516.884]      1
# Name: estimated_diameter.meters.estimated_diameter_max, dtype: int64
